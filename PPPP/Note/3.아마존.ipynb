# %%
import pandas as pd
import numpy as np

# %%
ama = pd.read_csv("../Data/Women Dresses Reviews Dataset .csv",index_col='s.no')
ama.head()
# Out:
#       age   division_name department_name class_name  clothing_id  \
# s.no
# 0      40         General         Bottoms      Jeans         1028
# 1      62  General Petite            Tops    Blouses          850
# 2      47  General Petite         Bottoms     Skirts          993
# 3      45  General Petite         Bottoms      Pants         1068
# 4      37       Initmates        Intimate       Swim           24
#
#                        title  \
# s.no
# 0       Amazing fit and wash
# 1         Lovely and unique!
# 2                        Meh
# 3                        Wow
# 4     Great for bigger busts
#
#                                             review_text  alike_feedback_count  \
# s.no
# 0     Like other reviewers i was hesitant to spend t...                     0
# 1     As is true of a bunch of the fall clothing pho...                    12
# 2     I so wanted this skirt to work, love the desig...                     3
# ...

# %%
len(ama)
# Out:
# 23486

# %%
np.sum(ama.isnull())
# Out:
# age                        0
# division_name             14
# department_name           14
# class_name                14
# clothing_id                0
# title                   3810
# review_text              845
# alike_feedback_count       0
# rating                     0
# recommend_index            0
# dtype: int64

# %%
# na_ama=ama.dropna()
na_ama = ama.dropna(how='any')

# %%
np.sum(na_ama.isnull())
# Out:
# age                     0
# division_name           0
# department_name         0
# class_name              0
# clothing_id             0
# title                   0
# review_text             0
# alike_feedback_count    0
# rating                  0
# recommend_index         0
# dtype: int64

# %%
len(na_ama)
# Out:
# 19662

# %%
na_ama
# Out:
#        age   division_name department_name class_name  clothing_id  \
# s.no
# 0       40         General         Bottoms      Jeans         1028
# 1       62  General Petite            Tops    Blouses          850
# 2       47  General Petite         Bottoms     Skirts          993
# 3       45  General Petite         Bottoms      Pants         1068
# 4       37       Initmates        Intimate       Swim           24
# ...    ...             ...             ...        ...          ...
# 23478   26         General            Tops      Knits          883
# 23481   44  General Petite         Dresses    Dresses         1081
# 23482   39         General         Dresses    Dresses         1110
# 23483   29  General Petite            Tops      Knits          862
# 23484   57         General         Dresses    Dresses         1082
#
#                                        title  \
# s.no
# 0                       Amazing fit and wash
# 1                         Lovely and unique!
# ...

# %%
na_ama.class_name.unique()
# Out:
# array(['Jeans', 'Blouses', 'Skirts', 'Pants', 'Swim', 'Sweaters', 'Knits',
#        'Fine gauge', 'Dresses', 'Shorts', 'Jackets', 'Outerwear',
#        'Lounge', 'Intimates', 'Legwear', 'Trend', 'Sleep', 'Layering',
#        'Casual bottoms', 'Chemises'], dtype=object)

# %%
na_ama.age.max()
# Out:
# 99

# %%
na_ama.age.min()
# Out:
# 18

# %%
Jeans = na_ama[na_ama.class_name == 'Jeans']

# %%
Jeans
# Out:
#        age   division_name department_name class_name  clothing_id  \
# s.no
# 0       40         General         Bottoms      Jeans         1028
# 55      39         General         Bottoms      Jeans         1039
# 58      34         General         Bottoms      Jeans         1038
# 65      42         General         Bottoms      Jeans         1028
# 83      52         General         Bottoms      Jeans         1033
# ...    ...             ...             ...        ...          ...
# 23357   36  General Petite         Bottoms      Jeans         1037
# 23365   48  General Petite         Bottoms      Jeans         1028
# 23396   36         General         Bottoms      Jeans         1033
# 23437   58         General         Bottoms      Jeans         1022
# 23474   46         General         Bottoms      Jeans         1030
#
#                               title  \
# s.no
# 0              Amazing fit and wash
# 55               I like them but...
# ...

# %%
Jeans.age >= 20
# Out:
# s.no
# 0        True
# 55       True
# 58       True
# 65       True
# 83       True
#          ...
# 23357    True
# 23365    True
# 23396    True
# 23437    True
# 23474    True
# Name: age, Length: 970, dtype: bool

# %%
# Out:
#   File "/var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_2019/3605360320.py", line 1
#     Jeans.age >= 20, ["age_point"] = 20
#     ^
# SyntaxError: cannot assign to comparison

# %%
# Out:
# 0        True
# 55       True
# 58       True
# 65       True
# 83       True
#          ...
# 23357    True
# 23365    True
# 23396    True
# 23437    True
# 23474    True
# Name: age, Length: 970, dtype: bool
