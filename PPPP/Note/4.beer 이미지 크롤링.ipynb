# %%
import pandas as pd
import numpy as np

# %%
beer = pd.read_csv('../data/beer_data_set.csv')
beer.head()
# Out:
#              Name  key    Style  Style Key                         Brewery  \
# 0           Amber  251  Altbier          8             Alaskan Brewing Co.
# 1      Double Bag  252  Altbier          8          Long Trail Brewing Co.
# 2  Long Trail Ale  253  Altbier          8          Long Trail Brewing Co.
# 3    Doppelsticke  254  Altbier          8  Uerige Obergärige Hausbrauerei
# 4          Scurry  255  Altbier          8               Off Color Brewing
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1  Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                             Notes:  8.5        4.15
# 4  Notes:Just cause it's dark and German doesn't ...  5.3        3.67
#
#    Min IBU  Max IBU  ...  Body  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  \
# ...

# %%
beer2 = beer.loc[:,['Name','Style']]
beer2
# Out:
#                                              Name          Style
# 0                                           Amber        Altbier
# 1                                      Double Bag        Altbier
# 2                                  Long Trail Ale        Altbier
# 3                                    Doppelsticke        Altbier
# 4                                          Scurry        Altbier
# ...                                           ...            ...
# 5553                          Red Nose Winter Ale  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  Winter Warmer
# 5555                         Fish Tale Winterfish  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  Winter Warmer
#
# [5558 rows x 2 columns]

# %%
# list(np.array(beer2))

# %%
for i in beer2.index:
   str = print(beer2['Name'][i] , beer2['Style'][i])
str
# Out:
# Amber Altbier
# Double Bag Altbier
# Long Trail Ale Altbier
# Doppelsticke Altbier
# Scurry Altbier
# Sleigh'r Dark Doüble Alt Ale Altbier
# Sticke Altbier
# Okto Festival Ale Altbier
# Southampton Altbier Altbier
# Copper Altbier
# Organic Münster Alt Altbier
# Altbier Altbier
# Gerst Amber Altbier
# Ad Astra Ale Altbier
# Doppel Sticky Altbier
# Copperhead Ale Altbier
# Ten Years Alt Altbier
# Three Blind Mice Altbier
# Ishmael Altbier
# Headwall Alt Altbier
# Alt-eration Ale Altbier
# Schell's Schmaltz's Alt Altbier
# Balt Altbier Altbier
# Frankenheim Alt Altbier
# Iron Works Alt Altbier
# Diebels Premium Altbier Altbier
# Mission Amber Altbier
# Hövels Original Altbier
# Secret Spot Alt Ale Altbier
# Hoppeditz Altbier
# Lighthouse Amber Altbier
# Copper ALT. Altbier
# Série Signature Sticke Alt Altbier
# Simple Means Altbier
# Crooked Coast Altbier Altbier
# Gravel Road Altbier
# Little Red Cap Altbier
# Festivale Altbier
# Duckstein Rotblondes Original Altbier
# Moby D Altbier
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %% [raw]
# https://www.google.com/search?q=%s

# %%
chrome_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
driver.get('https://www.google.com/webhp')
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - There is no [mac64] chromedriver for browser 103.0.5060 in cache
# [WDM] - About to download new driver from https://chromedriver.storage.googleapis.com/103.0.5060.134/chromedriver_mac64.zip
# [WDM] - Driver has been saved in cache [/Users/tj/.wdm/drivers/chromedriver/mac64/103.0.5060.134]

# %%
driver.save_screenshot("../Data/beer1/GoogleMain.png")
# Out:
# True

# %%
gu_list_raw = driver.find_element(By.XPATH, '//*[@id="_sK7gYqiHOqrR2roPmNyroAU28"]/div[1]/div/div[1]/a/g-inner-card/div/div')
gu_list =gu_list_raw.find_elements(By.TAG_NAME,'option')

gu_names= [option.get_attribute('value') for option in gu_list]

gu_names
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/51/xmc_l6t13wv1nc5z6qmyg58r0000gn/T/ipykernel_6191/1346931928.py in <module>
# ----> 1 gu_list_raw = driver.find_element(By.XPATH, '//*[@id="_sK7gYqiHOqrR2roPmNyroAU28"]/div[1]/div/div[1]/a/g-inner-card/div/div')
#       2 gu_list =gu_list_raw.find_elements(By.TAG_NAME,'option')
#       3
#       4 gu_names= [option.get_attribute('value') for option in gu_list]
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     855             value = '[name="%s"]' % value
#     856
# --> 857         return self.execute(Command.FIND_ELEMENT, {
#     858             'using': by,
#     859             'value': value})['value']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...
