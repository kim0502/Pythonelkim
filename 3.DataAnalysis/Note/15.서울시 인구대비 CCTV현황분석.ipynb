# %% [markdown]
# # 서울시 CCTV 현황 분석 및 인구 현황 분석

# %% [markdown]
# ### CCTV설치 현황

# %%
import pandas as pd

# %%
CCTV_Seoul = pd.read_excel("../Data/CCTV_in_Seoul_2018.xlsx")
CCTV_Seoul.head()
# Out:
#    기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
CCTV_Seoul.tail()
# Out:
#     기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 20  용산구  2063    1279.0  152.0  201.0    107    102     89     60     73
# 21  은평구  2962    1365.0   83.0   99.0    343    180    296    229    367
# 22  종로구  1471       8.0    7.0  599.0    132    195    148    281    101
# 23   중구  1544      25.0  165.0  114.0     80    245    270    317    328
# 24  중랑구  1068       NaN    NaN    NaN    770    102    121     66      9

# %%
CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2011년 이전', '2012년', '2013년', '2014년', '2015년', '2016년',
#        '2017년', '2018년'],
#       dtype='object')

# %%
# CCTV_Seoul의 첫번째 컬럼 확인
CCTV_Seoul.columns[0]
# Out:
# '기관명'

# %%
# 기관명 -> 구별로 변경
CCTV_Seoul.rename(columns={'기관명': '구별'}, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
# NaN을 확인하고 NaN을 0으로 대체하기
CCTV_Seoul=CCTV_Seoul.fillna(0)
CCTV_Seoul.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671

# %%
CCTV_Seoul.tail()
# Out:
#      구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 20  용산구  2063    1279.0  152.0  201.0    107    102     89     60     73
# 21  은평구  2962    1365.0   83.0   99.0    343    180    296    229    367
# 22  종로구  1471       8.0    7.0  599.0    132    195    148    281    101
# 23   중구  1544      25.0  165.0  114.0     80    245    270    317    328
# 24  중랑구  1068       0.0    0.0    0.0    770    102    121     66      9

# %% [markdown]
# ---
# ### 인구현황

# %%
pop_Seoul = pd.read_excel("../Data/population_in_Seoul_2020.xlsx")
pop_Seoul
# Out:
#       report Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         기간        자치구         세대         인구         인구         인구
# 1         기간        자치구         세대         합계         합계         합계
# 2         기간        자치구         세대          계         남자         여자
# 3   2020.1/4         합계    4354006   10013781    4874995    5138786
# 4   2020.1/4        종로구      74151     161984      78271      83713
# 5   2020.1/4         중구      63045     136469      66769      69700
# 6   2020.1/4        용산구     110895     246165     119961     126204
# 7   2020.1/4        성동구     135643     307193     149891     157302
# 8   2020.1/4        광진구     165287     365990     176226     189764
# 9   2020.1/4       동대문구     165279     362793     178202     184591
# 10  2020.1/4        중랑구     182220     400678     198122     202556
# 11  2020.1/4        성북구     193801     454532     218561     235971
# 12  2020.1/4        강북구     144805     316750     154141     162609
# ...

# %%
pop_Seoul.columns
# Out:
# Index(['report', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
# 엑셀에서 원하는 값만 가져오기
pop_Seoul = pd.read_excel("../Data/population_in_Seoul_2020.xlsx",
                          header=3,
                          usecols="B,D,G,J,N"  # 엑셀의 컬럼 번호로

                        )
pop_Seoul
# Out:
#      자치구         계      계.1     계.2  65세이상고령자
# 0     합계  10013781  9733655  280126   1518239
# 1    종로구    161984   151217   10767     28073
# 2     중구    136469   126175   10294     23794
# 3    용산구    246165   229579   16586     39439
# 4    성동구    307193   299042    8151     44728
# 5    광진구    365990   350417   15573     48989
# 6   동대문구    362793   346156   16637     60367
# 7    중랑구    400678   395619    5059     66764
# 8    성북구    454532   442494   12038     72172
# 9    강북구    316750   312985    3765     61660
# 10   도봉구    333495   331238    2257     60023
# 11   노원구    535495   531037    4458     82682
# 12   은평구    482509   478019    4490     82245
# 13  서대문구    325875   312642   13233     53038
# 14   마포구    386086   374570   11516     53283
# 15   양천구    460532   456339    4193     62761
# 16   강서구    595703   589302    6401     85992
# 17   구로구    438308   405837   32471     67432
# 18   금천구    251370   232583   18787     38508
# ...

# %%
pop_Seoul.columns = ['구별','인구수','한국인','외국인','고령자']
pop_Seoul.head()
# Out:
#     구별       인구수      한국인     외국인      고령자
# 0   합계  10013781  9733655  280126  1518239
# 1  종로구    161984   151217   10767    28073
# 2   중구    136469   126175   10294    23794
# 3  용산구    246165   229579   16586    39439
# 4  성동구    307193   299042    8151    44728

# %%
# 합계 행을 삭제
pop_Seoul.drop(0, inplace=True)
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 1  종로구  161984  151217  10767  28073
# 2   중구  136469  126175  10294  23794
# 3  용산구  246165  229579  16586  39439
# 4  성동구  307193  299042   8151  44728
# 5  광진구  365990  350417  15573  48989

# %%
pop_Seoul.tail()
# Out:
#      구별     인구수     한국인    외국인    고령자
# 21  관악구  516662  499374  17288  76664
# 22  서초구  434801  430568   4233  58332
# 23  강남구  549898  544804   5094  72602
# 24  송파구  680883  674095   6788  89539
# 25  강동구  457042  452646   4396  66401

# %% [markdown]
# ### CCTV 현황

# %%
# CCTV에서 소계로 오름차순 정렬
CCTV_Seoul.sort_values(by='소계', ascending=True).head()
# Out:
#      구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 9   도봉구   858     197.0   66.0    8.0    185     59    155    117     71
# 24  중랑구  1068       0.0    0.0    0.0    770    102    121     66      9
# 2   강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 22  종로구  1471       8.0    7.0  599.0    132    195    148    281    101
# 23   중구  1544      25.0  165.0  114.0     80    245    270    317    328

# %% [markdown]
# > CCTV 댓수가 적은 지역으로는 도봉구,중랑구, 강북구, 종로구, 중구 순이다.ㅡ

# %%
# CCTV에서 소계로 내림차순 정렬
CCTV_Seoul.sort_values(by='소계', ascending=False).head()
# Out:
#      구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0   강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 4   관악구  3985     430.0   56.0  419.0    487    609    619    694    671
# 6   구로구  3227     852.0  219.0  349.0    187    268    326    540    486
# 16  성북구  3003     779.0   84.0  304.0    241    279    388    285    643
# 21  은평구  2962    1365.0   83.0   99.0    343    180    296    229    367

# %% [markdown]
# > CCTV 댓수가 많은 지역으로는 강남구, 관악구, 구로구, 성북구, 은평구 순이다.

# %% [markdown]
# ---
# #### 최근 3년간 CCTV증가율 구해서 CCTV가 제일 많이 증가한 구를 검색후 정렬

# %%
a1 = CCTV_Seoul.iloc[:,2:7].sum(axis=1)
a2 = CCTV_Seoul.iloc[:,7:10].sum(axis=1)

# %%
CCTV_Seoul['최근증가율'] =  (a2 / a1) * 100

# %%
CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 23    중구  1544      25.0  165.0  114.0     80    245    270    317    328
# 19  영등포구  2495     132.0  121.0  206.0    217    366    289    371    793
# 15   성동구  2679     665.0  109.0  118.0    101    258    201    933    294
# 7    금천구  1634      27.0   17.0  242.0    101    382    136    199    530
# 5    광진구  1581     470.0   42.0   83.0     87     64     21    468    346
#
#          최근증가율
# 23  145.468998
# 19  139.443378
# 15  114.148681
# 7   112.483745
# 5   111.930295

# %% [markdown]
# > 결과를 보면 최근 3년간의 CCTV가 2015년 이전에 비해 가장 많이 증가한 곳은 중구, 영등포구, 성동구, 금천구, 광진구 순이다.

# %% [markdown]
# ---
# ### 인구현황

# %%
# 구별 Data의 유효성 확인
len(pop_Seoul['구별'].unique())
# Out:
# 25

# %%
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 1  종로구  161984  151217  10767  28073
# 2   중구  136469  126175  10294  23794
# 3  용산구  246165  229579  16586  39439
# 4  성동구  307193  299042   8151  44728
# 5  광진구  365990  350417  15573  48989

# %%
pop_Seoul['외국인비율']=pop_Seoul['외국인']/pop_Seoul['인구수']*100
pop_Seoul['고령자비율']=pop_Seoul['고령자']/pop_Seoul['인구수']*100
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  161984  151217  10767  28073  6.646953  17.330724
# 2   중구  136469  126175  10294  23794  7.543105  17.435462
# 3  용산구  246165  229579  16586  39439  6.737757  16.021368
# 4  성동구  307193  299042   8151  44728  2.653381  14.560228
# 5  광진구  365990  350417  15573  48989  4.255034  13.385338

# %%
# 인구수가 제일 많은 지역은 Top5
pop_Seoul.sort_values(by='인구수', ascending=False).head(5)
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  680883  674095   6788  89539  0.996941  13.150424
# 16  강서구  595703  589302   6401  85992  1.074529  14.435381
# 23  강남구  549898  544804   5094  72602  0.926354  13.202812
# 11  노원구  535495  531037   4458  82682  0.832501  15.440294
# 21  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
# 외국인이 제일 많은 지역은 Top5
pop_Seoul.sort_values(by='외국인', ascending=False).head(5)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 17   구로구  438308  405837  32471  67432  7.408261  15.384615
# 18   금천구  251370  232583  18787  38508  7.473843  15.319251
# 21   관악구  516662  499374  17288  76664  3.346095  14.838328
# 6   동대문구  362793  346156  16637  60367  4.585811  16.639516

# %%
# 외국인 비율이 높은 지역은 Top5
pop_Seoul.sort_values(by='외국인비율', ascending=False).head(5)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 2     중구  136469  126175  10294  23794  7.543105  17.435462
# 18   금천구  251370  232583  18787  38508  7.473843  15.319251
# 17   구로구  438308  405837  32471  67432  7.408261  15.384615
# 3    용산구  246165  229579  16586  39439  6.737757  16.021368

# %%
# 고령자 정렬
pop_Seoul.sort_values(by='고령자', ascending=False).head(5)
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  680883  674095   6788  89539  0.996941  13.150424
# 16  강서구  595703  589302   6401  85992  1.074529  14.435381
# 11  노원구  535495  531037   4458  82682  0.832501  15.440294
# 12  은평구  482509  478019   4490  82245  0.930553  17.045278
# 21  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
# 고령자 비율 정렬
pop_Seoul.sort_values(by='고령자비율', ascending=False).head(5)
# Out:
#      구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 9   강북구  316750  312985   3765  61660  1.188635  19.466456
# 10  도봉구  333495  331238   2257  60023  0.676772  17.998171
# 2    중구  136469  126175  10294  23794  7.543105  17.435462
# 1   종로구  161984  151217  10767  28073  6.646953  17.330724
# 12  은평구  482509  478019   4490  82245  0.930553  17.045278

# %% [raw]
# 분석 :
# 인구수가 제일 많은 지역은 송파구이지만 영등포구가 제일 외국인이 많다.
# 그리고 그 근처라고 할 수 있는 구로구, 금천구 등도 굉장히 외국인이 많다.
# 송파구는 고령자가 제일 많지만 고령자의 비율이 높지 않은 것이 확인된다.
# 하지만 강북구, 도봉구, 중구, 종로구, 은평구 같은 경우는
# 인구수 대비 고령자 비율이 많기 때문에 추후 고령화가 우려된다.

# %% [markdown]
# ---
# # CCTV와 인구현황 합치기

# %%
Data_result = pd.merge(CCTV_Seoul, pop_Seoul, on= '구별')
Data_result.head()
# Out:
#     구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관악구  3985     430.0   56.0  419.0    487    609    619    694    671
#
#        최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 0  52.171379  549898  544804   5094  72602  0.926354  13.202812
# 1  82.960078  457042  452646   4396  66401  0.961837  14.528424
# 2  83.068017  316750  312985   3765  61660  1.188635  19.466456
# 3  77.887789  595703  589302   6401  85992  1.074529  14.435381
# 4  99.150425  516662  499374  17288  76664  3.346095  14.838328

# %%
Data_result.set_index('구별', inplace=True)
Data_result.head()
# Out:
#        소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 구별
# 강남구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 강동구  1879     303.0  387.0  134.0     59    144    194    273    385
# 강북구  1265     243.0   88.0  141.0     74    145    254      1    319
# 강서구  1617     219.0  155.0  118.0    230    187    190    264    254
# 관악구  3985     430.0   56.0  419.0    487    609    619    694    671
#
#          최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 강남구  52.171379  549898  544804   5094  72602  0.926354  13.202812
# 강동구  82.960078  457042  452646   4396  66401  0.961837  14.528424
# 강북구  83.068017  316750  312985   3765  61660  1.188635  19.466456
# 강서구  77.887789  595703  589302   6401  85992  1.074529  14.435381
# 관악구  99.150425  516662  499374  17288  76664  3.346095  14.838328

# %%
# 구별을 index로 만들기
delColumn = Data_result.columns[2:9]

for i in delColumn:
    del Data_result[i]
Data_result.head()
# Out:
#        소계  2011년 이전      최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 강남구  5221    1944.0  52.171379  549898  544804   5094  72602  0.926354
# 강동구  1879     303.0  82.960078  457042  452646   4396  66401  0.961837
# 강북구  1265     243.0  83.068017  316750  312985   3765  61660  1.188635
# 강서구  1617     219.0  77.887789  595703  589302   6401  85992  1.074529
# 관악구  3985     430.0  99.150425  516662  499374  17288  76664  3.346095
#
#          고령자비율
# 구별
# 강남구  13.202812
# 강동구  14.528424
# 강북구  19.466456
# 강서구  14.435381
# 관악구  14.838328

# %%
import numpy as np

# %%
# 고령자 비율과 소계의 상관계수
np.corrcoef(Data_result['고령자비율'], Data_result['소계']) 
# 결과 : 역상관관계가 나온다.
# Out:
# array([[ 1.        , -0.44225083],
#        [-0.44225083,  1.        ]])

# %%
# 고령자와 소계의 상관계수
np.corrcoef(Data_result['고령자'], Data_result['소계'])
# 결과 : 상관이 없다.
# Out:
# array([[1.        , 0.28638538],
#        [0.28638538, 1.        ]])

# %%
# 외국인 비율과 소계의 상관계수 
np.corrcoef(Data_result['외국인비율'], Data_result['소계'])
# 결과 :상관이 없다.
# Out:
# array([[ 1.        , -0.06215538],
#        [-0.06215538,  1.        ]])

# %%
# 외국인과 소계의 상관계수
np.corrcoef(Data_result['외국인'], Data_result['소계'])
# 결과 : 상관없다.
# Out:
# array([[1.        , 0.17444235],
#        [0.17444235, 1.        ]])

# %%
# 인구수와 소계의 상관계수
np.corrcoef(Data_result['인구수'], Data_result['소계'])
# 결과 : 양의 상관이 있다.
# Out:
# array([[1.        , 0.38064812],
#        [0.38064812, 1.        ]])

# %% [markdown]
# > 고령자 비율의 상관계수를 보면 역상관이 발생하고 이는고령자가 아닌젊은 층 비율이 높은 곳에 CCTV가 많이 설치되는 경행을 보이며
# > 주로 인구수와 양의 상관을 보이고 있어 CCTV 댓수는 인구수에 비례하여 증가하는 경향을 보인다.

# %% [markdown]
# ---
# # 시각화

# %%
# import matplotlib as plot
from matplotlib import pyplot as plt
# 둘중 하나만 쓸 수 있다.

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
Data_result.head()
# Out:
#        소계  2011년 이전      최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 강남구  5221    1944.0  52.171379  549898  544804   5094  72602  0.926354
# 강동구  1879     303.0  82.960078  457042  452646   4396  66401  0.961837
# 강북구  1265     243.0  83.068017  316750  312985   3765  61660  1.188635
# 강서구  1617     219.0  77.887789  595703  589302   6401  85992  1.074529
# 관악구  3985     430.0  99.150425  516662  499374  17288  76664  3.346095
#
#          고령자비율
# 구별
# 강남구  13.202812
# 강동구  14.528424
# 강북구  19.466456
# 강서구  14.435381
# 관악구  14.838328

# %%
# 파일로 저장 (CCTV_result.csv)
Data_result.to_csv("../Data/CCTV_result.csv")

# %%
Data_result['소계'].plot(
    kind = 'barh',
    grid =True,
    figsize = (10,10)
)
# Out:
# <AxesSubplot:ylabel='구별'>

# %%
# 내림차순으로 소계 하기 

Data_result['소계'].sort_values().plot(
    kind = 'barh',
    grid =True,
    figsize = (10,10)
)
plt.show()

# %% [markdown]
# ---
# ### 인구 대비 CCTV 비율

# %%
Data_result.head()
# Out:
#        소계  2011년 이전      최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 강남구  5221    1944.0  52.171379  549898  544804   5094  72602  0.926354
# 강동구  1879     303.0  82.960078  457042  452646   4396  66401  0.961837
# 강북구  1265     243.0  83.068017  316750  312985   3765  61660  1.188635
# 강서구  1617     219.0  77.887789  595703  589302   6401  85992  1.074529
# 관악구  3985     430.0  99.150425  516662  499374  17288  76664  3.346095
#
#          고령자비율
# 구별
# 강남구  13.202812
# 강동구  14.528424
# 강북구  19.466456
# 강서구  14.435381
# 관악구  14.838328

# %%
Data_result['인구대비CCTV비율'] = Data_result['소계'] / Data_result['인구수'] *100 
Data_result.head()
# Out:
#        소계  2011년 이전      최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 강남구  5221    1944.0  52.171379  549898  544804   5094  72602  0.926354
# 강동구  1879     303.0  82.960078  457042  452646   4396  66401  0.961837
# 강북구  1265     243.0  83.068017  316750  312985   3765  61660  1.188635
# 강서구  1617     219.0  77.887789  595703  589302   6401  85992  1.074529
# 관악구  3985     430.0  99.150425  516662  499374  17288  76664  3.346095
#
#          고령자비율  인구대비CCTV비율
# 구별
# 강남구  13.202812    0.949449
# 강동구  14.528424    0.411122
# 강북구  19.466456    0.399369
# 강서구  14.435381    0.271444
# 관악구  14.838328    0.771297

# %%
Data_result['인구대비CCTV비율'].sort_values().plot(
    kind = 'barh',
    grid =True,
    figsize = (10,10)
)
# Out:
# <AxesSubplot:ylabel='구별'>

# %%
Data_result.sort_values(by='고령자비율', ascending=False).head(5)
# Out:
#        소계  2011년 이전       최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 강북구  1265     243.0   83.068017  316750  312985   3765  61660  1.188635
# 도봉구   858     197.0   66.601942  333495  331238   2257  60023  0.676772
# 중구   1544      25.0  145.468998  136469  126175  10294  23794  7.543105
# 종로구  1471       8.0   56.323061  161984  151217  10767  28073  6.646953
# 은평구  2962    1365.0   43.091787  482509  478019   4490  82245  0.930553
#
#          고령자비율  인구대비CCTV비율
# 구별
# 강북구  19.466456    0.399369
# 도봉구  17.998171    0.257275
# 중구   17.435462    1.131392
# 종로구  17.330724    0.908114
# 은평구  17.045278    0.613875

# %%
Data_result.sort_values(by='소계', ascending=False).head(5)
# Out:
#        소계  2011년 이전      최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 강남구  5221    1944.0  52.171379  549898  544804   5094  72602  0.926354
# 관악구  3985     430.0  99.150425  516662  499374  17288  76664  3.346095
# 구로구  3227     852.0  72.106667  438308  405837  32471  67432  7.408261
# 성북구  3003     779.0  78.008299  454532  442494  12038  72172  2.648438
# 은평구  2962    1365.0  43.091787  482509  478019   4490  82245  0.930553
#
#          고령자비율  인구대비CCTV비율
# 구별
# 강남구  13.202812    0.949449
# 관악구  14.838328    0.771297
# 구로구  15.384615    0.736240
# 성북구  15.878310    0.660680
# 은평구  17.045278    0.613875

# %%
Data_result.sort_values(by='외국인', ascending=False).head(5)
# Out:
#         소계  2011년 이전       최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 영등포구  2495     132.0  139.443378  404766  371903  32863  59373  8.119012
# 구로구   3227     852.0   72.106667  438308  405837  32471  67432  7.408261
# 금천구   1634      27.0  112.483745  251370  232583  18787  38508  7.473843
# 관악구   3985     430.0   99.150425  516662  499374  17288  76664  3.346095
# 동대문구  2003       0.0   39.387613  362793  346156  16637  60367  4.585811
#
#           고령자비율  인구대비CCTV비율
# 구별
# 영등포구  14.668475    0.616406
# 구로구   15.384615    0.736240
# 금천구   15.319251    0.650038
# 관악구   14.838328    0.771297
# 동대문구  16.639516    0.552105

# %%
Data_result.sort_values(by='인구대비CCTV비율', ascending=False).head(5)
# Out:
#        소계  2011년 이전       최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 중구   1544      25.0  145.468998  136469  126175  10294  23794  7.543105
# 강남구  5221    1944.0   52.171379  549898  544804   5094  72602  0.926354
# 종로구  1471       8.0   56.323061  161984  151217  10767  28073  6.646953
# 성동구  2679     665.0  114.148681  307193  299042   8151  44728  2.653381
# 용산구  2063    1279.0   12.058664  246165  229579  16586  39439  6.737757
#
#          고령자비율  인구대비CCTV비율
# 구별
# 중구   17.435462    1.131392
# 강남구  13.202812    0.949449
# 종로구  17.330724    0.908114
# 성동구  14.560228    0.872090
# 용산구  16.021368    0.838056

# %%
np.corrcoef(Data_result['소계'], Data_result['인구대비CCTV비율'])
# Out:
# array([[1.       , 0.5205078],
#        [0.5205078, 1.       ]])

# %%
np.corrcoef(Data_result['인구수'], Data_result['인구대비CCTV비율'])
# Out:
# array([[ 1.        , -0.50235996],
#        [-0.50235996,  1.        ]])

# %%
np.corrcoef(Data_result['외국인'], Data_result['인구대비CCTV비율'])
# Out:
# array([[1.        , 0.28946317],
#        [0.28946317, 1.        ]])

# %%
np.corrcoef(Data_result['외국인비율'], Data_result['인구대비CCTV비율'])
# Out:
# array([[1.        , 0.55493223],
#        [0.55493223, 1.        ]])

# %%
np.corrcoef(Data_result['고령자'], Data_result['인구대비CCTV비율'])
# Out:
# array([[ 1.        , -0.58493587],
#        [-0.58493587,  1.        ]])

# %%
np.corrcoef(Data_result['고령자비율'], Data_result['인구대비CCTV비율'])
# Out:
# array([[1.        , 0.03144259],
#        [0.03144259, 1.        ]])

# %%
# 산점도 이용한 시각화 (인구수와 소계)

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
# 산점도 이용한 시각화 (인구수와 소계)

plt.figure(figsize=(6,6))
plt.scatter(Data_result['인구수'], Data_result['소계'])
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
#  인구수, 소계에 따른 기준직선(희귀선, 평균선) 만들기
fp1 = np.polyfit(Data_result['인구수'], Data_result['소계'],1)
fp1
# Out:
# array([2.88522756e-03, 1.06403852e+03])

# %%
# x축 만들기 : 인구수 표현
fx = np.linspace(100000, 700000)

# y축 데이터 만들기 : CCTV 소계 표현
f1 = np.poly1d(fp1)

print(fx)
print(f1) # 회귀식이 나옴 즉 , array([2.88522756e-03, 1.06403852e+03]) 이 회귀식이라는거임.

plt.figure(figsize=(10, 10))
plt.scatter(Data_result['인구수'], Data_result['소계'])
plt.plot(fx, f1(fx), ls = 'dashed', lw=3, color= 'r') # 기준직선 그려주기
plt.xlabel('안구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()
# Out:
# [100000.         112244.89795918 124489.79591837 136734.69387755
#  148979.59183673 161224.48979592 173469.3877551  185714.28571429
#  197959.18367347 210204.08163265 222448.97959184 234693.87755102
#  246938.7755102  259183.67346939 271428.57142857 283673.46938776
#  295918.36734694 308163.26530612 320408.16326531 332653.06122449
#  344897.95918367 357142.85714286 369387.75510204 381632.65306122
#  393877.55102041 406122.44897959 418367.34693878 430612.24489796
#  442857.14285714 455102.04081633 467346.93877551 479591.83673469
#  491836.73469388 504081.63265306 516326.53061224 528571.42857143
#  540816.32653061 553061.2244898  565306.12244898 577551.02040816
#  589795.91836735 602040.81632653 614285.71428571 626530.6122449
#  638775.51020408 651020.40816327 663265.30612245 675510.20408163
#  687755.10204082 700000.        ]
#
# 0.002885 x + 1064

# %% [markdown]
# > 이 직선은 CCTV 댓수에 기준값이 됩니다.
# > 이 직선을 기준으로 상위에 있는 점은 과하게 설치 된것이고
# > 직선 보다 하위에 있는 점은 인구수에 비해 CCTV가 부족하다는 해석이 됩니다.

# %%
# 기준선 구하기
fp1 = np.polyfit(Data_result['인구수'], Data_result['소계'], 1)

# 기준치 구하기
f1 = np.poly1d(fp1)
f1

# 인구수
fx = np.linspace(100000, 700000)
fx

# 소계에서 기준인구수 차이로 오차값 구하기
Data_result['오차'] = np.abs(Data_result['소계']-f1(Data_result['인구수'])) 
# abs :   값이 -가 있기에 절대값으로 보여주어야한다.




# 정렬
df_sort = Data_result.sort_values(by = '오차', ascending=False)
df_sort.head()
# Out:
#        소계  2011년 이전      최근증가율     인구수     한국인    외국인    고령자     외국인비율  \
# 구별
# 강남구  5221    1944.0  52.171379  549898  544804   5094  72602  0.926354
# 송파구  1586     600.0  62.833676  680883  674095   6788  89539  0.996941
# 관악구  3985     430.0  99.150425  516662  499374  17288  76664  3.346095
# 도봉구   858     197.0  66.601942  333495  331238   2257  60023  0.676772
# 강서구  1617     219.0  77.887789  595703  589302   6401  85992  1.074529
#
#          고령자비율  인구대비CCTV비율           오차
# 구별
# 강남구  13.202812    0.949449  2570.380612
# 송파구  13.150424    0.232933  1442.540920
# 관악구  14.838328    0.771297  1430.274035
# 도봉구  17.998171    0.257275  1168.247488
# 강서구  14.435381    0.271444  1165.777237

# %%
# 그래프에  텍스트와 Color
plt.figure(figsize=( 14, 10))
plt.scatter(Data_result['인구수'], Data_result['소계'], c =Data_result['오차'])
plt.plot(fx, f1(fx), ls = 'dashed', lw=3, color= 'r')

# 오차가 가장 큰 10개구 텍스트 붙이기
#plt.text(500000, 3000, 'Text')

for n in range(10):
    plt.text(df_sort['인구수'][n]* 1.02, df_sort['소계'][n]*0.98, df_sort.index[n], fontsize=15)
#1.02,0.98 : 위치
# df_sort 는 정렬이 되어있다. 정렬이 되어야 가능



plt.xlabel('인구수')
plt.ylabel('CCTV 댓수')
plt.colorbar()
plt.grid()
plt.show()
